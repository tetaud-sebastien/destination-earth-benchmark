# %% [markdown]
# <table style="width:100%; border: none;">
#     <tr>
#         <td colspan="3" style="text-align:center; border: none;">
#             <img src="assets/banner.svg" alt="Banner Image" style="width:100%;">
#         </td>
#     </tr>
#     <!-- Add other rows and cells below if needed -->
# </table>

# %%
from utils import load_capitals_coordinates, create_map_with_forecast
capitals_coordinates = load_capitals_coordinates(file_path="config.yaml")
m = create_map_with_forecast(capitals_coordinates=capitals_coordinates,
                             forecast_folder="results/cacheb",
                             map_center=(48.8566, 2.3522),
                             zoom=6,
                             output_file='map.html')

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_36951b145ae263e747eb8434fe61c397 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_36951b145ae263e747eb8434fe61c397&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_36951b145ae263e747eb8434fe61c397 = L.map(
#                 &quot;map_36951b145ae263e747eb8434fe61c397&quot;,
#                 {
#                     center: [48.8566, 2.3522],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_07fc9155f5fabef43eac45d29abd7c81 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_07fc9155f5fabef43eac45d29abd7c81.addTo(map_36951b145ae263e747eb8434fe61c397);
#
#
#             var marker_96b1a77e9b4cbc15db97b2d4de7e3eb6 = L.marker(
#                 [48.2082, 16.3738],
#                 {}
#             ).addTo(map_36951b145ae263e747eb8434fe61c397);
#
#
#             var icon_605bef55e0ee6e28891e702c2bf41ca8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;circle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkblue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_96b1a77e9b4cbc15db97b2d4de7e3eb6.setIcon(icon_605bef55e0ee6e28891e702c2bf41ca8);
#
#
#         var popup_28406fe4d278e5d46b90b692315f95b2 = L.popup({&quot;maxWidth&quot;: 1000});
#
#
#
#                 var html_65e09966b6368f408cc18cbc5d37592e = $(`&lt;div id=&quot;html_65e09966b6368f408cc18cbc5d37592e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;img src=&quot;data:image/svg+xml;base64,...&quot; alt=&quot;DT-Climate Forecast Vienna&quot; width=&quot;1000&quot; height=&quot;500&quot;&gt;&lt;/div&gt;`)[0];
#                 popup_28406fe4d278e5d46b90b692315f95b2.setContent(html_65e09966b6368f408cc18cbc5d37592e);
#
#
#
#         marker_96b1a77e9b4cbc15db97b2d4de7e3eb6.bindPopup(popup_28406fe4d278e5d46b90b692315f95b2)
#         ;
#
#
#
#
#             var marker_37aeb458a2963b8e1b50498fd2d71f58 = L.marker(
#                 [50.8503, 4.3517],
#                 {}
#             ).addTo(map_36951b145ae263e747eb8434fe61c397);
#
#
#             var icon_35fa605b298b5bf031b86b0cb3f41450 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;circle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkblue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_37aeb458a2963b8e1b50498fd2d71f58.setIcon(icon_35fa605b298b5bf031b86b0cb3f41450);
#
#
#         var popup_64b8f4af2b5b53d69a726b1ff76f0ab9 = L.popup({&quot;maxWidth&quot;: 1000});
#
#
#
#                 var html_b87413671697cfc1ddb300c66d7d12be = $(`&lt;div id=&quot;html_b87413671697cfc1ddb300c66d7d12be&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;img src=&quot;data:image/svg+xml;base64,...&quot; alt=&quot;DT-Climate Forecast Brussels&quot; width=&quot;1000&quot; height=&quot;500&quot;&gt;&lt;/div&gt;`)[0];
#                 popup_64b8f4af2b5b53d69a726b1ff76f0ab9.setContent(html_b87413671697cfc1ddb300c66d7d12be);
#
#
#
#         marker_37aeb458a2963b8e1b50498fd2d71f58.bindPopup(popup_64b8f4af2b5b53d69a726b1ff76f0ab9)
#         ;
#
#
#
#
#             var marker_96b7accf0212f797a6a287519fd54aeb = L.marker(
#                 [42.6977, 23.3219],
#                 {}
#             ).addTo(map_36951b145ae263e747eb8434fe61c397);
#
#
#             var icon_770af6325e8934e36662b7830db1bd79 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;circle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkblue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_96b7accf0212f797a6a287519fd54aeb.setIcon(icon_770af6325e8934e36662b7830db1bd79);
#
#
#         var popup_e460a7b70e5fb3d317fffe10c500aad9 = L.popup({&quot;maxWidth&quot;: 1000});
#
#
#
#                 var html_cdbf85f8190477bfdf0f12214be3e5a7 = $(`&lt;div id=&quot;html_cdbf85f8190477bfdf0f12214be3e5a7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;img src=&quot;data:image/svg+xml;base64,...&quot; alt=&quot;DT-Climate Forecast Sofia&quot; width=&quot;1000&quot; height=&quot;500&quot;&gt;&lt;/div&gt;`)[0];
#                 popup_e460a7b70e5fb3d317fffe10c500aad9.setContent(html_cdbf85f8190477bfdf0f12214be3e5a7);
#
#
#
#         marker_96b7accf0212f797a6a287519fd54aeb.bindPopup(popup_e460a7b70e5fb3d317fffe10c500aad9)
#         ;
#
#
#
#
#             var marker_bae7bbebb140f98fee7ff904f09a8ca1 = L.marker(
#                 [45.815, 15.9819],
