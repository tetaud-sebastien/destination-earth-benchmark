# %%
from utils import load_config, CdsERA5, WindSpeedVisualizer

# %%
config = load_config("config.yaml")
query = config["cds_request"]

# %%
cds = CdsERA5()
cds.get_data(query=query)
cds.download(filename="ERA5")
wind_speed, ds = cds.process()
# Out:
# 2024-06-14 09:17:23.737 | INFO     | utils:__init__:133 - Successfully log to Climate Data Store
# 2024-06-14 09:17:23,928 INFO Welcome to the CDS
# 2024-06-14 09:17:23,929 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-era5-single-levels
# 2024-06-14 09:17:24,035 INFO Request is completed
# 2024-06-14 09:17:24,036 INFO Downloading https://download-0008-clone.copernicus-climate.eu/cache-compute-0008/cache/data4/adaptor.mars.internal-1718287969.5438614-24478-15-21ddc1aa-5151-42a4-8af1-d75e2568294e.grib to ERA5.grib (122.8M)
# 2024-06-14 09:17:32,103 INFO Download rate 15.2M/s
# Ignoring index file 'ERA5.grib.9093e.idx' older than GRIB file

# %%
wind_anim = WindSpeedVisualizer.plot_wind_speed(wind_speed.sel(time=wind_speed.time[0]))

# %%
wind_anim = WindSpeedVisualizer.generate_animation(wind_speed)

# %%
wind_anim
# Out:
# <video width="1200" height="800" controls autoplay loop>
#   <source type="video/mp4" src="...
