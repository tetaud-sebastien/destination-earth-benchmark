# %%
from utils import ParticleVisualizer, CamsERA5, load_config
import matplotlib.animation as MatPlotAnimation
import pandas as pd
import xarray as xr
import cdsapi
import os

# %%
# config = load_config(file_path="config.yaml")
# query = config["cams_request"]

# client = CamsERA5()
# client.get_data(query=query)
# client.download(filename="CAMS")

# %%
ds = xr.open_dataset("../cams.eaq.ira.ENSa.pm10.l0.2023-01.nc", engine="netcdf4")
ds
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/env/lib/python3.11/site-packages/xarray/backends/file_manager.py:211, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     210 try:
# --> 211     file = self._cache[self._key]
#     212 except KeyError:
#
# File ~/miniconda3/envs/env/lib/python3.11/site-packages/xarray/backends/lru_cache.py:56, in LRUCache.__getitem__(self, key)
#      55 with self._lock:
# ---> 56     value = self._cache[key]
#      57     self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('/home/ilja/programming/destination-earth-benchmark/cams/cams.eaq.ira.ENSa.pm10.l0.2023-01.nc',), 'r', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False)), 'c9127484-b3b0-444f-828e-67beda8e9813']
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
ParticleVisualizer.plot_pm10_concentration(ds.pm10.sel(time=ds.time[0]))
pm10_anim = ParticleVisualizer.generate_animation(ds)
writervideo = MatPlotAnimation.FFMpegWriter(fps=20) 
pm10_anim.save('pm10.mp4', writer=writervideo)
